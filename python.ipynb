# %% [markdown]
# List

# %%
name=["meena","kavi","arun"]
name.append("kavya")
marks=[50,40,80]
print(name)
print(marks[2])
print(len(name))
print(len(marks))
# Out:
# ['meena', 'kavi', 'arun', 'kavya']
# 80
# 4
# 3

# %% [markdown]
# Tuple

# %%
days=("Monday","Tuesday","Wednesday")
print(days[1])
# Out:
# Tuesday
