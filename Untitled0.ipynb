# %%
name="Sakthi"
age=26
CGPA=8.5
placed=True
print("Student Name",name)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
# Out:
# Student Name Sakthi
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
