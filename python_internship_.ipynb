# %% [markdown]
# Python basic

# %%
name="Sakthi"
age=26
CGPA=8.5
placed=True
print("Student Name",name)
print("age",age)
print("CGPA",CGPA)
print("placed",placed)
print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))
print(len(name))
# Out:
# Student Name Sakthi
# age 26
# CGPA 8.5
# placed True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 6

# %% [markdown]
# List

# %%
name=["sakthi","rithi","kavi"]
name.append("mega")
marks=[50,60,90]
print(name)
print(marks[2])
print(len(name))
print(len(marks))
# Out:
# ['sakthi', 'rithi', 'kavi', 'mega']
# 90
# 4
# 3

# %% [markdown]
# Tuple

# %%
days=("Mpnday","Tuesday","Wednesday")
print(days[1])
# Out:
# Tuesday

# %% [markdown]
# Dictionary

# %%
student={
    "name":"Arun",
    "age":20
}

# %% [markdown]
# NumPy(Numerical Python)

# %%
import numpy as np
marks=np.array([80,40,30,50])
print(marks)
# Out:
# [80 40 30 50]

# %% [markdown]
# ACTIVITY

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([5,6,7])
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)
print(a**b)
# Out:
# [ 6  8 10]
# [-4 -4 -4]
# [ 5 12 21]
# [0.2        0.33333333 0.42857143]
# [1 2 3]
# [0 0 0]
# [   1   64 2187]
